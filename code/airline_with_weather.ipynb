# %% [markdown]
# # ADS507_Team1_Final_Project

# %%
#Import libraries
import numpy as np
import pandas as pd
import pymysql as mysql
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Airline data

# %%
#connectting the sql
conn2=mysql.connect(host='localhost',
                   port=int(3306),
                   user='root',
                   passwd='******',
                   db='airline')

# %%
#Show tables
tableNames2 = pd.read_sql("""SHOW TABLES""", conn2)
tableNames2
# Out:
#                      Tables_in_airline
# 0                         l_airline_id
# 1                            l_airport
# 2                         l_airport_id
# 3                     l_airport_seq_id
# 4                       l_cancellation
# 5                     l_city_market_id
# 6                          l_deparrblk
# 7                 l_distance_group_250
# 8                         l_diversions
# 9                             l_months
# 10               l_ontime_delay_groups
# 11                          l_quarters
# 12                l_state_abr_aviation
# 13                        l_state_fips
# 14                   l_unique_carriers
# 15                          l_weekdays
# 16                  l_world_area_codes
# 17                        l_yesno_resp
# 18  on_time_on_time_performance_2016_1

# %%
airline_table = """SELECT * FROM on_time_on_time_performance_2016_1 """
airline_df =  pd.read_sql(airline_table, conn2)
# Out:
#         Year  Quarter  Month  DayofMonth  DayOfWeek  FlightDate UniqueCarrier  \
# 0       2016        1      1           6          3  2016-01-06            AA
# 1       2016        1      1           7          4  2016-01-07            AA
# 2       2016        1      1           8          5  2016-01-08            AA
# 3       2016        1      1           9          6  2016-01-09            AA
# 4       2016        1      1          10          7  2016-01-10            AA
# ...      ...      ...    ...         ...        ...         ...           ...
# 445822  2016        1      1           3          7  2016-01-03            F9
# 445823  2016        1      1           3          7  2016-01-03            F9
# 445824  2016        1      1           3          7  2016-01-03            F9
# 445825  2016        1      1           3          7  2016-01-03            F9
# 445826  2016        1      1           3          7  2016-01-03            F9
#
#         AirlineID Carrier TailNum  ...  Div1TotalGTime  Div1LongestGTime  \
# 0           19805      AA  N4YBAA  ...             NaN               NaN
# 1           19805      AA  N434AA  ...             NaN               NaN
# 2           19805      AA  N541AA  ...             NaN               NaN
# 3           19805      AA  N489AA  ...             NaN               NaN
# 4           19805      AA  N439AA  ...             NaN               NaN
# ...           ...     ...     ...  ...             ...               ...
# 445822      20436      F9  N934FR  ...             NaN               NaN
# 445823      20436      F9  N934FR  ...             NaN               NaN
# 445824      20436      F9  N935FR  ...             NaN               NaN
# 445825      20436      F9  N935FR  ...             NaN               NaN
# 445826      20436      F9  N935FR  ...             NaN               NaN
#
#         Div1WheelsOff  Div1TailNum Div2Airport Div2AirportID Div2AirportSeqID  \
# 0                 NaN         None        None           NaN              NaN
# 1                 NaN         None        None           NaN              NaN
# 2                 NaN         None        None           NaN              NaN
# 3                 NaN         None        None           NaN              NaN
# 4                 NaN         None        None           NaN              NaN
# ...               ...          ...         ...           ...              ...
# 445822            NaN         None        None           NaN              NaN
# 445823            NaN         None        None           NaN              NaN
# 445824            NaN         None        None           NaN              NaN
# 445825            NaN         None        None           NaN              NaN
# 445826            NaN         None        None           NaN              NaN
#
#         Div2WheelsOn Div2TotalGTime  Div2LongestGTime
# 0                NaN            NaN               NaN
# 1                NaN            NaN               NaN
# 2                NaN            NaN               NaN
# 3                NaN            NaN               NaN
# 4                NaN            NaN               NaN
# ...              ...            ...               ...
# 445822           NaN            NaN               NaN
# 445823           NaN            NaN               NaN
# 445824           NaN            NaN               NaN
# 445825           NaN            NaN               NaN
# 445826           NaN            NaN               NaN
#
# [445827 rows x 83 columns]

# %%
airline_df
# Out:
#         Year  Quarter  Month  DayofMonth  DayOfWeek  FlightDate UniqueCarrier  \
# 0       2016        1      1           6          3  2016-01-06            AA
# 1       2016        1      1           7          4  2016-01-07            AA
# 2       2016        1      1           8          5  2016-01-08            AA
# 3       2016        1      1           9          6  2016-01-09            AA
# 4       2016        1      1          10          7  2016-01-10            AA
# ...      ...      ...    ...         ...        ...         ...           ...
# 445822  2016        1      1           3          7  2016-01-03            F9
# 445823  2016        1      1           3          7  2016-01-03            F9
# 445824  2016        1      1           3          7  2016-01-03            F9
# 445825  2016        1      1           3          7  2016-01-03            F9
# 445826  2016        1      1           3          7  2016-01-03            F9
#
#         AirlineID Carrier TailNum  ...  Div1TotalGTime  Div1LongestGTime  \
# 0           19805      AA  N4YBAA  ...             NaN               NaN
# 1           19805      AA  N434AA  ...             NaN               NaN
# 2           19805      AA  N541AA  ...             NaN               NaN
# 3           19805      AA  N489AA  ...             NaN               NaN
# 4           19805      AA  N439AA  ...             NaN               NaN
# ...           ...     ...     ...  ...             ...               ...
# 445822      20436      F9  N934FR  ...             NaN               NaN
# 445823      20436      F9  N934FR  ...             NaN               NaN
# 445824      20436      F9  N935FR  ...             NaN               NaN
# 445825      20436      F9  N935FR  ...             NaN               NaN
# 445826      20436      F9  N935FR  ...             NaN               NaN
#
#         Div1WheelsOff  Div1TailNum Div2Airport Div2AirportID Div2AirportSeqID  \
# 0                 NaN         None        None           NaN              NaN
# 1                 NaN         None        None           NaN              NaN
# 2                 NaN         None        None           NaN              NaN
# 3                 NaN         None        None           NaN              NaN
# 4                 NaN         None        None           NaN              NaN
# ...               ...          ...         ...           ...              ...
# 445822            NaN         None        None           NaN              NaN
# 445823            NaN         None        None           NaN              NaN
# 445824            NaN         None        None           NaN              NaN
# 445825            NaN         None        None           NaN              NaN
# 445826            NaN         None        None           NaN              NaN
#
#         Div2WheelsOn Div2TotalGTime  Div2LongestGTime
# 0                NaN            NaN               NaN
# 1                NaN            NaN               NaN
# 2                NaN            NaN               NaN
# 3                NaN            NaN               NaN
# 4                NaN            NaN               NaN
# ...              ...            ...               ...
# 445822           NaN            NaN               NaN
# 445823           NaN            NaN               NaN
# 445824           NaN            NaN               NaN
# 445825           NaN            NaN               NaN
# 445826           NaN            NaN               NaN
#
# [445827 rows x 83 columns]

# %%
airline_df.shape
# Out:
# (445827, 83)

# %%
airline_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 445827 entries, 0 to 445826
# Data columns (total 83 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   Year                  445827 non-null  int64
#  1   Quarter               445827 non-null  int64
#  2   Month                 445827 non-null  int64
#  3   DayofMonth            445827 non-null  int64
#  4   DayOfWeek             445827 non-null  int64
#  5   FlightDate            445827 non-null  object
#  6   UniqueCarrier         445827 non-null  object
#  7   AirlineID             445827 non-null  int64
#  8   Carrier               445827 non-null  object
#  9   TailNum               441583 non-null  object
#  10  FlightNum             445827 non-null  int64
#  11  OriginAirportID       445827 non-null  int64
#  12  OriginAirportSeqID    445827 non-null  int64
#  13  OriginCityMarketID    445827 non-null  int64
#  14  Origin                445827 non-null  object
#  15  OriginCityName        445827 non-null  object
#  16  OriginState           445827 non-null  object
#  17  OriginStateFips       445827 non-null  int64
#  18  OriginStateName       445827 non-null  object
#  19  OriginWac             445827 non-null  int64
#  20  DestAirportID         445827 non-null  int64
#  21  DestAirportSeqID      445827 non-null  int64
#  22  DestCityMarketID      445827 non-null  int64
#  23  Dest                  445827 non-null  object
#  24  DestCityName          445827 non-null  object
#  25  DestState             445827 non-null  object
#  26  DestStateFips         445827 non-null  int64
#  27  DestStateName         445827 non-null  object
#  28  DestWac               445827 non-null  int64
#  29  CRSDepTime            445827 non-null  int64
#  30  DepTime               434354 non-null  float64
#  31  DepDelay              434354 non-null  float64
#  32  DepDelayMinutes       434354 non-null  float64
#  33  DepDel15              434354 non-null  float64
#  34  DepartureDelayGroups  434354 non-null  float64
#  35  DepTimeBlk            445827 non-null  object
#  36  TaxiOut               434227 non-null  float64
#  37  WheelsOff             434227 non-null  float64
#  38  WheelsOn              433920 non-null  float64
#  39  TaxiIn                433920 non-null  float64
#  40  CRSArrTime            445827 non-null  int64
#  41  ArrTime               433920 non-null  float64
#  42  ArrDelay              433298 non-null  float64
#  43  ArrDelayMinutes       433298 non-null  float64
#  44  ArrDel15              433298 non-null  float64
#  45  ArrivalDelayGroups    433298 non-null  float64
#  46  ArrTimeBlk            445827 non-null  object
#  47  Cancelled             445827 non-null  int64
#  48  CancellationCode      11665 non-null   object
#  49  Diverted              445827 non-null  int64
#  50  CRSElapsedTime        445827 non-null  float64
#  51  ActualElapsedTime     433298 non-null  float64
#  52  AirTime               433298 non-null  float64
#  53  Flights               445827 non-null  float64
#  54  Distance              445827 non-null  float64
#  55  DistanceGroup         445827 non-null  int64
#  56  CarrierDelay          70882 non-null   float64
#  57  WeatherDelay          70882 non-null   float64
#  58  NASDelay              70882 non-null   float64
#  59  SecurityDelay         70882 non-null   float64
#  60  LateAircraftDelay     70882 non-null   float64
#  61  FirstDepTime          2552 non-null    float64
#  62  TotalAddGTime         2552 non-null    float64
#  63  LongestAddGTime       2552 non-null    float64
#  64  DivAirportLandings    445827 non-null  int64
#  65  DivReachedDest        864 non-null     float64
#  66  DivActualElapsedTime  622 non-null     float64
#  67  DivArrDelay           622 non-null     float64
#  68  DivDistance           864 non-null     float64
#  69  Div1Airport           929 non-null     object
#  70  Div1AirportID         929 non-null     float64
#  71  Div1AirportSeqID      929 non-null     float64
#  72  Div1WheelsOn          929 non-null     float64
#  73  Div1TotalGTime        929 non-null     float64
#  74  Div1LongestGTime      929 non-null     float64
#  75  Div1WheelsOff         628 non-null     float64
#  76  Div1TailNum           628 non-null     object
#  77  Div2Airport           6 non-null       object
#  78  Div2AirportID         6 non-null       float64
#  79  Div2AirportSeqID      6 non-null       float64
#  80  Div2WheelsOn          6 non-null       float64
#  81  Div2TotalGTime        6 non-null       float64
#  82  Div2LongestGTime      6 non-null       float64
# dtypes: float64(42), int64(23), object(18)
# memory usage: 282.3+ MB

# %%
airline_df.describe()
# Out:
#            Year   Quarter     Month     DayofMonth      DayOfWeek  \
# count  445827.0  445827.0  445827.0  445827.000000  445827.000000
# mean     2016.0       1.0       1.0      15.893510       4.113815
# std         0.0       0.0       0.0       8.936692       2.005007
# min      2016.0       1.0       1.0       1.000000       1.000000
# 25%      2016.0       1.0       1.0       8.000000       2.000000
# 50%      2016.0       1.0       1.0      16.000000       4.000000
# 75%      2016.0       1.0       1.0      24.000000       6.000000
# max      2016.0       1.0       1.0      31.000000       7.000000
#
#            AirlineID      FlightNum  OriginAirportID  OriginAirportSeqID  \
# count  445827.000000  445827.000000    445827.000000        4.458270e+05
# mean    19903.085069    2078.856456     12682.120789        1.268215e+06
# std       382.853084    1757.269780      1529.485604        1.529483e+05
# min     19393.000000       1.000000     10135.000000        1.013503e+06
# 25%     19790.000000     702.000000     11292.000000        1.129202e+06
# 50%     19805.000000    1594.000000     12889.000000        1.288903e+06
# 75%     20304.000000    2763.000000     14027.000000        1.402702e+06
# max     21171.000000    7438.000000     16218.000000        1.621801e+06
#
#        OriginCityMarketID  ...  Div1AirportSeqID  Div1WheelsOn  \
# count       445827.000000  ...      9.290000e+02    929.000000
# mean         31723.938281  ...      1.302242e+06   1426.447793
# std           1280.460591  ...      1.626952e+05    521.502184
# min          30070.000000  ...      1.013503e+06      1.000000
# 25%          30615.000000  ...      1.129804e+06   1036.000000
# 50%          31453.000000  ...      1.320402e+06   1442.000000
# 75%          32467.000000  ...      1.463502e+06   1834.000000
# max          35991.000000  ...      1.622902e+06   2358.000000
#
#        Div1TotalGTime  Div1LongestGTime  Div1WheelsOff  Div2AirportID  \
# count      929.000000        929.000000     628.000000       6.000000
# mean        26.743811         21.470398    1488.385350   12694.333333
# std         28.628435         24.184087     500.923391    1442.397818
# min          2.000000          2.000000       1.000000   10721.000000
# 25%          9.000000          7.000000    1138.750000   11797.000000
# 50%         19.000000         13.000000    1505.000000   12889.000000
# 75%         33.000000         25.000000    1844.250000   13337.500000
# max        293.000000        173.000000    2355.000000   14747.000000
#
#        Div2AirportSeqID  Div2WheelsOn  Div2TotalGTime  Div2LongestGTime
# count      6.000000e+00      6.000000            6.00              6.00
# mean       1.269436e+06   1287.166667            6.00              6.00
# std        1.442401e+05    947.880249            2.00              2.00
# min        1.072102e+06    111.000000            4.00              4.00
# 25%        1.179702e+06    451.500000            5.00              5.00
# 50%        1.288903e+06   1588.500000            5.00              5.00
# 75%        1.333752e+06   1925.250000            7.25              7.25
# max        1.474703e+06   2325.000000            9.00              9.00
#
# [8 rows x 65 columns]

# %%
#Find the duplicates
airline_df.duplicated().sum()
# Out:
# 0

# %%
#unique values
airline_df['UniqueCarrier'].unique()
# Out:
# array(['AA', 'AS', 'B6', 'DL', 'F9', 'OO', 'HA', 'NK', 'EV', 'UA', 'WN',
#        'VX'], dtype=object)

# %%
#unique values
airline_df['UniqueCarrier'].unique()
# Out:
# array(['AA', 'AS', 'B6', 'DL', 'F9', 'OO', 'HA', 'NK', 'EV', 'UA', 'WN',
#        'VX'], dtype=object)

# %%
### Find the Null values
airline_df.isnull().sum()
# Out:
# Year                     0
# Quarter                  0
# Month                    0
# DayofMonth               0
# DayOfWeek                0
#                      ...
# Div2AirportID       445821
# Div2AirportSeqID    445821
# Div2WheelsOn        445821
# Div2TotalGTime      445821
# Div2LongestGTime    445821
# Length: 83, dtype: int64

# %%
### Visualize the Unique counts
sns.countplot(airline_df['Month']).unique()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-21-c9eed422a867> in <module>
#       1 ### Visualize the Unique counts
# ----> 2 sns.countplot(airline_df['Month']).unique()
#
# AttributeError: 'AxesSubplot' object has no attribute 'unique'

# %% [markdown]
# ### WEATHER DATA

# %%
### Load the Data
weather_data = pd.DataFrame(pd.read_csv('WeatherUS_2016 (1).csv'))

# %%
weather_data.head()
# Out:
#    Unnamed: 0 EventId  Type Severity       StartTime(UTC)  \
# 0           0     W-1  Snow    Light  2016-01-06 23:14:00
# 1           1     W-2  Snow    Light  2016-01-07 04:14:00
# 2           2     W-3  Snow    Light  2016-01-07 05:54:00
# 3           3     W-4  Snow    Light  2016-01-08 05:34:00
# 4           4     W-5  Snow    Light  2016-01-08 13:54:00
#
#           EndTime(UTC)  Precipitation(in)     TimeZone AirportCode  \
# 0  2016-01-07 00:34:00               0.00  US/Mountain        K04V
# 1  2016-01-07 04:54:00               0.00  US/Mountain        K04V
# 2  2016-01-07 15:34:00               0.03  US/Mountain        K04V
# 3  2016-01-08 05:54:00               0.00  US/Mountain        K04V
# 4  2016-01-08 15:54:00               0.00  US/Mountain        K04V
#
#    LocationLat  LocationLng      City    County State  ZipCode
# 0      38.0972    -106.1689  Saguache  Saguache    CO  81149.0
# 1      38.0972    -106.1689  Saguache  Saguache    CO  81149.0
# 2      38.0972    -106.1689  Saguache  Saguache    CO  81149.0
# 3      38.0972    -106.1689  Saguache  Saguache    CO  81149.0
# 4      38.0972    -106.1689  Saguache  Saguache    CO  81149.0

# %%
weather_data.shape
# Out:
# (1185991, 15)

# %%
weather_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1185991 entries, 0 to 1185990
# Data columns (total 15 columns):
#  #   Column             Non-Null Count    Dtype
# ---  ------             --------------    -----
#  0   Unnamed: 0         1185991 non-null  int64
#  1   EventId            1185991 non-null  object
#  2   Type               1185991 non-null  object
#  3   Severity           1185991 non-null  object
#  4   StartTime(UTC)     1185991 non-null  object
#  5   EndTime(UTC)       1185991 non-null  object
#  6   Precipitation(in)  1185991 non-null  float64
#  7   TimeZone           1185991 non-null  object
#  8   AirportCode        1185991 non-null  object
#  9   LocationLat        1185991 non-null  float64
#  10  LocationLng        1185991 non-null  float64
#  11  City               1184461 non-null  object
#  12  County             1185991 non-null  object
#  13  State              1185991 non-null  object
#  14  ZipCode            1177494 non-null  float64
# dtypes: float64(4), int64(1), object(10)
# memory usage: 135.7+ MB

# %%
weather_data.describe()
# Out:
#          Unnamed: 0  Precipitation(in)   LocationLat   LocationLng  \
# count  1.185991e+06       1.185991e+06  1.185991e+06  1.185991e+06
# mean   3.766146e+06       1.138823e-01  3.882525e+01 -9.258823e+01
# std    2.162479e+06       1.823154e+00  5.575401e+00  1.342531e+01
# min    0.000000e+00       0.000000e+00  2.455710e+01 -1.245550e+02
# 25%    1.912022e+06       0.000000e+00  3.449780e+01 -9.851840e+01
# 50%    3.770805e+06       0.000000e+00  3.942560e+01 -9.073970e+01
# 75%    5.654580e+06       5.000000e-02  4.323370e+01 -8.252010e+01
# max    7.476864e+06       1.104130e+03  4.894020e+01 -6.779280e+01
#
#             ZipCode
# count  1.177494e+06
# mean   5.404086e+04
# std    2.534854e+04
# min    1.022000e+03
# 25%    3.254100e+04
# 50%    5.505100e+04
# 75%    7.523500e+04
# max    9.936200e+04

# %%
#Find the duplicates
weather_data.duplicated().sum()
# Out:
# 0

# %%
#unique values
weather_data['Type'].unique()
# Out:
# array(['Snow', 'Fog', 'Cold', 'Storm', 'Rain', 'Precipitation', 'Hail'],
#       dtype=object)

# %%
#unique values
weather_data['Severity'].unique()
# Out:
# array(['Light', 'Severe', 'Moderate', 'Heavy', 'UNK', 'Other'],
#       dtype=object)

# %%
#unique values
weather_data['State'].unique()
# Out:
# array(['CO', 'OK', 'MN', 'LA', 'WI', 'ID', 'MI', 'KS', 'WY', 'MA', 'MO',
#        'NM', 'NC', 'SC', 'RI', 'VA', 'CT', 'OR', 'ND', 'CA', 'NY', 'OH',
#        'SD', 'AZ', 'NV', 'IA', 'TX', 'GA', 'NE', 'TN', 'AL', 'IL', 'AR',
#        'WA', 'IN', 'UT', 'FL', 'WV', 'MS', 'PA', 'ME', 'MD', 'NJ', 'KY',
#        'VT', 'MT', 'NH', 'DE'], dtype=object)

# %%
### Visualize the Unique counts
sns.countplot(weather_data['Type']).unique()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-45-332d84ba9e4d> in <module>
#       1 ### Visualize the Unique counts
# ----> 2 sns.countplot(weather_data['Type']).unique()
#
# AttributeError: 'AxesSubplot' object has no attribute 'unique'

# %%
### Find the Null values
weather_data.isnull().sum()
# Out:
# Unnamed: 0              0
# EventId                 0
# Type                    0
# Severity                0
# StartTime(UTC)          0
# EndTime(UTC)            0
# Precipitation(in)       0
# TimeZone                0
# AirportCode             0
# LocationLat             0
# LocationLng             0
# City                 1530
# County                  0
# State                   0
# ZipCode              8497
# dtype: int64

# %%
### Correlation Plot - EDA
weather_data.corr()
# Out:
#                    Unnamed: 0  Precipitation(in)  LocationLat  LocationLng  \
# Unnamed: 0           1.000000           0.001700    -0.037486    -0.043632
# Precipitation(in)    0.001700           1.000000    -0.005381     0.010087
# LocationLat         -0.037486          -0.005381     1.000000    -0.171228
# LocationLng         -0.043632           0.010087    -0.171228     1.000000
# ZipCode              0.040073          -0.007616     0.029786    -0.920196
#
#                     ZipCode
# Unnamed: 0         0.040073
# Precipitation(in) -0.007616
# LocationLat        0.029786
# LocationLng       -0.920196
# ZipCode            1.000000

# %%
weather_data.head()
# Out:
#    Unnamed: 0 EventId  Type Severity       StartTime(UTC)  \
# 0           0     W-1  Snow    Light  2016-01-06 23:14:00
# 1           1     W-2  Snow    Light  2016-01-07 04:14:00
# 2           2     W-3  Snow    Light  2016-01-07 05:54:00
# 3           3     W-4  Snow    Light  2016-01-08 05:34:00
# 4           4     W-5  Snow    Light  2016-01-08 13:54:00
#
#           EndTime(UTC)  Precipitation(in)     TimeZone AirportCode  \
# 0  2016-01-07 00:34:00               0.00  US/Mountain        K04V
# 1  2016-01-07 04:54:00               0.00  US/Mountain        K04V
# 2  2016-01-07 15:34:00               0.03  US/Mountain        K04V
# 3  2016-01-08 05:54:00               0.00  US/Mountain        K04V
# 4  2016-01-08 15:54:00               0.00  US/Mountain        K04V
#
#    LocationLat  LocationLng      City    County State  ZipCode
# 0      38.0972    -106.1689  Saguache  Saguache    CO  81149.0
# 1      38.0972    -106.1689  Saguache  Saguache    CO  81149.0
# 2      38.0972    -106.1689  Saguache  Saguache    CO  81149.0
# 3      38.0972    -106.1689  Saguache  Saguache    CO  81149.0
# 4      38.0972    -106.1689  Saguache  Saguache    CO  81149.0

# %%
### Removing unnecessary columns
Reduced_df = weather_data.drop(['Unnamed: 0', 'EventId','TimeZone','LocationLat','LocationLng','County','ZipCode'], axis=1)
Reduced_df.head()
# Out:
#    Type Severity       StartTime(UTC)         EndTime(UTC)  Precipitation(in)  \
# 0  Snow    Light  2016-01-06 23:14:00  2016-01-07 00:34:00               0.00
# 1  Snow    Light  2016-01-07 04:14:00  2016-01-07 04:54:00               0.00
# 2  Snow    Light  2016-01-07 05:54:00  2016-01-07 15:34:00               0.03
# 3  Snow    Light  2016-01-08 05:34:00  2016-01-08 05:54:00               0.00
# 4  Snow    Light  2016-01-08 13:54:00  2016-01-08 15:54:00               0.00
#
#   AirportCode      City State
# 0        K04V  Saguache    CO
# 1        K04V  Saguache    CO
# 2        K04V  Saguache    CO
# 3        K04V  Saguache    CO
# 4        K04V  Saguache    CO

# %%
### Rename the coolumns
Reduced_df.rename(
    columns={"StartTime(UTC)": "StartTime_UTC", "EndTime(UTC)": "EndTime_UTC", "Precipitation(in)": "Precipitation_in"},
    inplace=True,
)
Reduced_df.head()
# Out:
#    Type Severity        StartTime_UTC          EndTime_UTC  Precipitation_in  \
# 0  Snow    Light  2016-01-06 23:14:00  2016-01-07 00:34:00              0.00
# 1  Snow    Light  2016-01-07 04:14:00  2016-01-07 04:54:00              0.00
# 2  Snow    Light  2016-01-07 05:54:00  2016-01-07 15:34:00              0.03
# 3  Snow    Light  2016-01-08 05:34:00  2016-01-08 05:54:00              0.00
# 4  Snow    Light  2016-01-08 13:54:00  2016-01-08 15:54:00              0.00
#
#   AirportCode      City State
# 0        K04V  Saguache    CO
# 1        K04V  Saguache    CO
# 2        K04V  Saguache    CO
# 3        K04V  Saguache    CO
# 4        K04V  Saguache    CO
